# %% [markdown]
# <a href="https://colab.research.google.com/github/hdiiaamir/SD-HADIYA-0110/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input())
arr = [int(input()) for _ in range(n)]

sum_even = 0
for i in range(n):
    if i % 2 == 0:
        sum_even += arr[i]
    print("Sum is", sum_even)

# %%
name= input("Enter your name ");
 course= input("Enter your course ");
 branch= input("Enter your branch ");
 roll= input("Enter your roll number ");
 marks= int(input("Enter your marks "));
if (marks>=80):

    print("you will be a part of A0 batch");

elif (marks>=60 and marks<80):

    print("you will be a part of A1 batch");

elif (marks>=40 and marks<60):

    print("you will be a part of A2 batch");

else:

    print("you will be a part of A3 batch");

# %%
x=input()
if x==(x[::-1]):
  print("palindrome")
else:
  print("not pallindrome")

# %%
keys=[]
values=[]
for item in dict1.items():
  keys.append(item[0]),values.append(item[1])

  print("keys:",keys)
  print("values:",values)

# %%
l = [1, 2.5, 'hello', 4, 'world', 3.0]
l1_num = []
l2_str = []

for i in l:
  if type(i) == int or type(i) == float:
    l1_num.append(i)
  else:
    l2_str.append(i)

print("Numbers:", l1_num)
print("Strings/Others:", l2_str)
